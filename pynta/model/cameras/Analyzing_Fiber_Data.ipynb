# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(15, 15))
mpl.rc('image', cmap='gray')

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

from pynta.model.cameras.sim_fiber_brownian import SimBrownian
SimBrownian.num_particles = 20
SimBrownian.signal = 255
sb = SimBrownian(camera_size=(15, 1000), movie_length=500)
import pims
import trackpy as tp

# %%
@pims.pipeline
def gray(image):
    return np.sum(image, 2)  # Take just the green channel

# %%
frames = gray(pims.open('test/*.png'))

# %%
frames

# %%
frames[0]

# %%
img = sb.gen_image()
f = tp.locate(img.astype(np.uint8), 5, invert=False)

# %%
f.head()

# %%
features = []
i = 0
for img in sb:
    features.append(tp.locate(img.astype(np.uint8), 5, invert=False))
    print(f'Done with frame {i}')
    i+=1

# %%
data = np.array((1000, 500), dtype=np.int)

# %%
i = 0
for

# %%
SimBrownian.num_particles = 10
SimBrownian.drift = .05
sb = SimBrownian(camera_size=(15, 1000), movie_length=500)
new_image = np.zeros(shape=(1000, 500))
i = 0
for img in sb:
    new_image[:, i] = np.sum(img,0)
    i+=1

# %%
plt.imshow(new_image.T)
plt.xlabel('Position (px)', fontsize=18)
plt.ylabel('Time (frames)', fontsize=18)
# Out:
# Text(0, 0.5, 'Time (frames)')

# %%
plt.plot(np.sum(img,0))
